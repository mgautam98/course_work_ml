# %% [markdown]
# # # Linear regression and logistic regression with Regularization

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.datasets import make_regression
import seaborn as sns
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/__init__.py:874: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
X, y, cof = make_regression(n_samples=500, n_features=1, bias=4.2, noise=24, coef=True)
print X.shape, y.shape, cof
# Out:
# (500, 1) (500,) 15.9548559142

# %%
plt.xlim(-200, 200)
plt.ylim(-200, 200)
sns.plt.scatter(X[:, 0], y)

# %%
split = int(0.8 * X.shape[0])

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

print X_train.shape, X_test.shape
print y_train.shape, y_test.shape
# Out:
# (400, 1) (100, 1)
# (400,) (100,)

# %%
# hypothesis function
def hypothesis(x, w):
    return x*w[1] + w[0]

# error compute
def get_error(y_true, x, w):
    err = 0.0
    
    # Get number of examples
    m = x.shape[0]
    for ix in range(m):
        # for each example compute the square error
        err += (y_true[ix] - hypothesis(x[ix], w))**2
    # Get mean sq. error
    err = err / (2*m)
    return err

# error gradient
def get_grads(y_true, x, w, lam=0):
    grad_00 = 0.0
    grad_01 = 0.0
    
    # Get number of examples
    m = x.shape[0]
    
    for ix in range(m):
        # for each example compute the gradients
        grad_00 += (y_true[ix] - hypothesis(x[ix], w))*(-1)
        grad_01 += (y_true[ix] - hypothesis(x[ix], w))*(-1*x[ix]) + lam*w[1]
    
    # Get mean grads
    grad_00 = grad_00 / m
    grad_01 = grad_01 / m
    return [grad_00, grad_01]

# update weights using grad. desc.
def grad_descent(x, y_true, w, learning_rate=0.1):
    error = get_error(y_true, x, w)
    [grad_00, grad_01] = get_grads(y_true, x, w)
    
    w[0] = w[0] - learning_rate*grad_00
    w[1] = w[1] - learning_rate*grad_01
    
    return error, w

# %%
W = np.array([0.1, 0.1])
loss = []

# %%
sns.plt.scatter(X[:, 0], y)

y_0 = hypothesis(-3, W)
y_1 = hypothesis(3, W)

plt.plot([-3, 3], [y_0, y_1], 'r*-')
plt.show()



l, W = grad_descent(X_train, y_train, W, learning_rate=0.03)
loss.append(l)
